# %%
import os
import graphviz
import time
import pickle
import csv

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from time import time

# ML Scikit Imports
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, ConfusionMatrixDisplay

# tensorflow imports
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LambdaCallback

ANN_MODEL_CSV_FOLDER = os.path.join("./", "artificial_neural_network_mfcc/")
if not os.path.exists(ANN_MODEL_CSV_FOLDER):
    os.makedirs(ANN_MODEL_CSV_FOLDER)
ANN_MODEL_JSON = os.path.join(ANN_MODEL_CSV_FOLDER, "artificial_neural_network_mfcc.json")
ANN_MODEL_H5 = os.path.join(ANN_MODEL_CSV_FOLDER, "artificial_neural_network_mfcc.h5")
ANN_MODEL_H5_WEIGHTS = os.path.join(ANN_MODEL_CSV_FOLDER, "artificial_neural_network_mfcc_weights.h5")
ANN_MODEL_HISTORY = os.path.join(ANN_MODEL_CSV_FOLDER, "artificial_neural_network_mfcc_history.txt")

# %%
# Load compressed models from tensorflow_hub
import os
os.environ['TFHUB_MODEL_LOAD_FORMAT'] = 'COMPRESSED'

# links with google drive and colab
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/gdrive')

if IN_COLAB:
   from google.colab import drive
   drive.mount('/content/gdrive')
   code_folder = '/content/gdrive/My Drive/Colab Notebooks/ENSTA/EML/training/artificial_neural_network'
   # %cd "$code_folder"
   # !ls "$code_folder"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/Colab Notebooks/ENSTA/EML/training/artificial_neural_network
# artificial_neural_network_mfcc	      artificial_neural_network_stft
# artificial_neural_network_mfcc.ipynb  artificial_neural_network_stft.ipynb

# %% [markdown]
# ### Extract the dataset from the .au csv files

# %%
print("Extracting dataset training set...")
dataset = '../../datasets/music_features_mfcc_train.csv'
musics_df = pd.read_csv(dataset, header=0)
# Get all style values
Y_train = musics_df["style"].values
# Get all features names
features_name = musics_df.columns.values[:-2]
# Get all features values
# musics_df = musics_df.drop('style', axis=1)
# musics_df = musics_df.drop('file_name', axis=1)
# X = musics_df.values
X_train = musics_df.loc[:, ~musics_df.columns.isin(['style', 'file_name'])].values
unique_label_names = np.unique(X_train)
input_shape = X_train.shape[1]

print("File contains {} unique_label_names: ".format(len(unique_label_names), unique_label_names))
print("File contains {} lines of {} data ".format(X_train.shape[0], X_train.shape[1]))

print("Extracting dataset testing set...")
dataset = '../../datasets/music_features_mfcc_test.csv'
musics_df = pd.read_csv(dataset, header=0)
# Get all style values
Y_test = musics_df["style"].values
# Get all features names
features_name = musics_df.columns.values[:-2]
# Get all features values
# musics_df = musics_df.drop('style', axis=1)
# musics_df = musics_df.drop('file_name', axis=1)
# X = musics_df.values
X_test = musics_df.loc[:, ~musics_df.columns.isin(['style', 'file_name'])].values
unique_label_names = np.unique(Y_test)

print("File contains {} unique_label_names: ".format(len(unique_label_names), unique_label_names))
print("File contains {} lines of {} data ".format(X_test.shape[0], X_test.shape[1]))
# Out:
# Extracting dataset training set...
# File contains 31103 unique_label_names:
# File contains 799 lines of 42 data
# Extracting dataset testing set...
# File contains 10 unique_label_names:
# File contains 201 lines of 42 data

# %% [markdown]
# ### Create the train, validation and test dataset for tensorflow

# %%
# Create Validation dataset
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, stratify=np.array(Y_train), random_state=42)

#Ttransform classes str to int
enc_str2int = preprocessing.LabelEncoder()
enc_str2int.fit(np.unique(Y_train))
Y_train = enc_str2int.transform(Y_train)
Y_test = enc_str2int.transform(Y_test)
Y_val = enc_str2int.transform(Y_val)

# Convert dataset into tf.data.Dataset
ds_train = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
ds_val = tf.data.Dataset.from_tensor_slices((X_val, Y_val))
ds_test = tf.data.Dataset.from_tensor_slices((X_test, Y_test))

# Shuffle 1000 times the training set and add batching & prefetching
batch_size = 16
dataset_size = X_train.shape[0]
train_set = ds_train.shuffle(1000).repeat()
train_set = train_set.batch(batch_size).prefetch(1)
valid_set = ds_val.batch(batch_size).prefetch(1)
test_set = ds_test.batch(batch_size).prefetch(1)

print("Train set format: ", train_set)
print("Test set format: ", test_set)
print("Validation set format :", valid_set)
# Out:
# Train set format:  <PrefetchDataset shapes: ((None, 42), (None,)), types: (tf.float64, tf.int64)>
# Test set format:  <PrefetchDataset shapes: ((None, 42), (None,)), types: (tf.float64, tf.int64)>
# Validation set format : <PrefetchDataset shapes: ((None, 42), (None,)), types: (tf.float64, tf.int64)>

# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# ### Optimize model using cross validation

# %%
loss="sparse_categorical_crossentropy"
# optimizer = keras.optimizers.SGD(learning_rate=0.2, momentum=0.9, decay=0.01)
optimizer = keras.optimizers.Adam(learning_rate=0.001)
metrics = ["accuracy"]

print("Creating Artificial Neural Network model...")
ann_model = Sequential()
ann_model.add(Dense(input_shape = (input_shape,), units=input_shape/1.5, activation="relu", name="dense_1"))
# ann_model.add(Dense(input_shape = (input_shape,), units=input_shape/2, activation="relu", name="dense_2"))
# output layer of size 1x1xn_classes
ann_model.add(Dense(units=len(unique_label_names), activation="softmax", name="output"))

print("Model summary: ")
ann_model.summary()
# Out:
# Creating Artificial Neural Network model...
# Model summary:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 28)                1204
#
#  output (Dense)              (None, 10)                290
#
# =================================================================
# Total params: 1,494
# Trainable params: 1,494
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
ann_model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
# Use early stoping to stop the learning once the mode lperformances stop improving
early_stop = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=500, verbose=1, mode='auto')
# model_cp = ModelCheckpoint(SVM_MODEL_H5_WEIGHTS, monitor='val_loss',  verbose=1, save_best_only=True, save_weights_only=True, mode='auto')
# Save the best model observed during training for later use

best_val_acc = 0
best_val_loss = sys.float_info.max 

def save_model(epoch, logs):
    global best_val_acc, best_val_loss
    val_acc = logs['val_accuracy']
    val_loss = logs['val_loss']
    if val_acc > best_val_acc and (val_loss-best_val_loss<0.5)  :
        best_val_loss=val_loss
        print("\nvall acc improved from {} to {}, vall loss improved from {} to {}, saving model to best_model variable".format(best_val_acc, val_acc, best_val_loss, val_loss))
        best_val_acc = val_acc
        # Save model weights
        ann_model.save_weights(ANN_MODEL_H5_WEIGHTS)
        print("Model weights saved to disk")

# %%
# Learnign stage
t_start = time()
history = ann_model.fit(train_set,
                    validation_data=valid_set,
                    epochs=1000,
                    verbose=1,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks=[LambdaCallback(on_epoch_end=save_model), early_stop])
print("Training done in {}s".format(time()-t_start))
# Out:
# Epoch 1/1000
# 18/29 [=================>............] - ETA: 0s - loss: 2.6326 - accuracy: 0.1007
# vall acc improved from 0 to 0.02500000037252903, vall loss improved from 2.452451229095459 to 2.452451229095459, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 7ms/step - loss: 2.5827 - accuracy: 0.0927 - val_loss: 2.4525 - val_accuracy: 0.0250
# Epoch 2/1000
# 22/29 [=====================>........] - ETA: 0s - loss: 2.3935 - accuracy: 0.0909
# vall acc improved from 0.02500000037252903 to 0.05000000074505806, vall loss improved from 2.343508243560791 to 2.343508243560791, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 2.3837 - accuracy: 0.0948 - val_loss: 2.3435 - val_accuracy: 0.0500
# Epoch 3/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 2.3062 - accuracy: 0.1013 - val_loss: 2.2939 - val_accuracy: 0.0125
# Epoch 4/1000
# 24/29 [=======================>......] - ETA: 0s - loss: 2.2742 - accuracy: 0.1354
# vall acc improved from 0.05000000074505806 to 0.15000000596046448, vall loss improved from 2.250427484512329 to 2.250427484512329, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 4ms/step - loss: 2.2728 - accuracy: 0.1207 - val_loss: 2.2504 - val_accuracy: 0.1500
# Epoch 5/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 2.2480 - accuracy: 0.1616 - val_loss: 2.2324 - val_accuracy: 0.1250
# Epoch 6/1000
# 22/29 [=====================>........] - ETA: 0s - loss: 2.2367 - accuracy: 0.1932
# vall acc improved from 0.15000000596046448 to 0.22499999403953552, vall loss improved from 2.198615312576294 to 2.198615312576294, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 2.2360 - accuracy: 0.1789 - val_loss: 2.1986 - val_accuracy: 0.2250
# Epoch 7/1000
# 25/29 [========================>.....] - ETA: 0s - loss: 2.2228 - accuracy: 0.2975
# vall acc improved from 0.22499999403953552 to 0.3375000059604645, vall loss improved from 2.172147750854492 to 2.172147750854492, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 2.2215 - accuracy: 0.2974 - val_loss: 2.1721 - val_accuracy: 0.3375
# Epoch 8/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 2.2013 - accuracy: 0.2371 - val_loss: 2.1544 - val_accuracy: 0.3250
# Epoch 9/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 2.1600 - accuracy: 0.2866 - val_loss: 2.1170 - val_accuracy: 0.3125
# Epoch 10/1000
# 22/29 [=====================>........] - ETA: 0s - loss: 2.1611 - accuracy: 0.2415
# vall acc improved from 0.3375000059604645 to 0.3499999940395355, vall loss improved from 2.097992420196533 to 2.097992420196533, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 2.1384 - accuracy: 0.2909 - val_loss: 2.0980 - val_accuracy: 0.3500
# Epoch 11/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 2.1595 - accuracy: 0.2586 - val_loss: 2.0792 - val_accuracy: 0.3375
# Epoch 12/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 2.1206 - accuracy: 0.2823 - val_loss: 2.0632 - val_accuracy: 0.3500
# Epoch 13/1000
# 25/29 [========================>.....] - ETA: 0s - loss: 2.1060 - accuracy: 0.2775
# vall acc improved from 0.3499999940395355 to 0.4124999940395355, vall loss improved from 2.0436348915100098 to 2.0436348915100098, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 2.0933 - accuracy: 0.2996 - val_loss: 2.0436 - val_accuracy: 0.4125
# Epoch 14/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 2.0811 - accuracy: 0.3664 - val_loss: 2.0098 - val_accuracy: 0.3875
# Epoch 15/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 2.0596 - accuracy: 0.3082 - val_loss: 1.9863 - val_accuracy: 0.3875
# Epoch 16/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 2.0269 - accuracy: 0.3319 - val_loss: 1.9769 - val_accuracy: 0.3875
# Epoch 17/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 2.0438 - accuracy: 0.3082 - val_loss: 1.9529 - val_accuracy: 0.4000
# Epoch 18/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.9901 - accuracy: 0.3707 - val_loss: 1.9419 - val_accuracy: 0.3875
# Epoch 19/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.9924 - accuracy: 0.3319 - val_loss: 1.9126 - val_accuracy: 0.3625
# Epoch 20/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.9793 - accuracy: 0.3578 - val_loss: 1.8926 - val_accuracy: 0.4125
# Epoch 21/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 1.9584 - accuracy: 0.3297 - val_loss: 1.8853 - val_accuracy: 0.4000
# Epoch 22/1000
# 21/29 [====================>.........] - ETA: 0s - loss: 1.9345 - accuracy: 0.3720
# vall acc improved from 0.4124999940395355 to 0.4625000059604645, vall loss improved from 1.8585329055786133 to 1.8585329055786133, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 4ms/step - loss: 1.9486 - accuracy: 0.3384 - val_loss: 1.8585 - val_accuracy: 0.4625
# Epoch 23/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.9033 - accuracy: 0.3815 - val_loss: 1.8383 - val_accuracy: 0.4375
# Epoch 24/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.9491 - accuracy: 0.3233 - val_loss: 1.8363 - val_accuracy: 0.4500
# Epoch 25/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.8603 - accuracy: 0.4030 - val_loss: 1.8177 - val_accuracy: 0.4375
# Epoch 26/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.8920 - accuracy: 0.3297 - val_loss: 1.7968 - val_accuracy: 0.4625
# Epoch 27/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.8744 - accuracy: 0.3836 - val_loss: 1.7822 - val_accuracy: 0.4625
# Epoch 28/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.8683 - accuracy: 0.3793 - val_loss: 1.7850 - val_accuracy: 0.4625
# Epoch 29/1000
# 23/29 [======================>.......] - ETA: 0s - loss: 1.8302 - accuracy: 0.4130
# vall acc improved from 0.4625000059604645 to 0.48750001192092896, vall loss improved from 1.7468982934951782 to 1.7468982934951782, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 1.8512 - accuracy: 0.3966 - val_loss: 1.7469 - val_accuracy: 0.4875
# Epoch 30/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.8268 - accuracy: 0.4246 - val_loss: 1.7409 - val_accuracy: 0.4750
# Epoch 31/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.8179 - accuracy: 0.3966 - val_loss: 1.7281 - val_accuracy: 0.4750
# Epoch 32/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.7995 - accuracy: 0.3987 - val_loss: 1.7131 - val_accuracy: 0.4875
# Epoch 33/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.8108 - accuracy: 0.3836 - val_loss: 1.6977 - val_accuracy: 0.4125
# Epoch 34/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.7780 - accuracy: 0.4224 - val_loss: 1.6950 - val_accuracy: 0.4875
# Epoch 35/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.8029 - accuracy: 0.4138 - val_loss: 1.6784 - val_accuracy: 0.4750
# Epoch 36/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.7633 - accuracy: 0.4009 - val_loss: 1.6749 - val_accuracy: 0.4750
# Epoch 37/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.7501 - accuracy: 0.4138 - val_loss: 1.6550 - val_accuracy: 0.4625
# Epoch 38/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.7505 - accuracy: 0.4332 - val_loss: 1.6533 - val_accuracy: 0.4250
# Epoch 39/1000
# 25/29 [========================>.....] - ETA: 0s - loss: 1.7332 - accuracy: 0.4225
# vall acc improved from 0.48750001192092896 to 0.5, vall loss improved from 1.6500526666641235 to 1.6500526666641235, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 1.7364 - accuracy: 0.4246 - val_loss: 1.6501 - val_accuracy: 0.5000
# Epoch 40/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.7522 - accuracy: 0.4095 - val_loss: 1.6261 - val_accuracy: 0.4625
# Epoch 41/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.7548 - accuracy: 0.4116 - val_loss: 1.6256 - val_accuracy: 0.4750
# Epoch 42/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.7038 - accuracy: 0.4440 - val_loss: 1.6275 - val_accuracy: 0.4750
# Epoch 43/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.7125 - accuracy: 0.4504 - val_loss: 1.5990 - val_accuracy: 0.4875
# Epoch 44/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6974 - accuracy: 0.4440 - val_loss: 1.5917 - val_accuracy: 0.4750
# Epoch 45/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6757 - accuracy: 0.4375 - val_loss: 1.5830 - val_accuracy: 0.4625
# Epoch 46/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6712 - accuracy: 0.4504 - val_loss: 1.5896 - val_accuracy: 0.4875
# Epoch 47/1000
# 26/29 [=========================>....] - ETA: 0s - loss: 1.6766 - accuracy: 0.4159
# vall acc improved from 0.5 to 0.512499988079071, vall loss improved from 1.572542428970337 to 1.572542428970337, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6794 - accuracy: 0.4224 - val_loss: 1.5725 - val_accuracy: 0.5125
# Epoch 48/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6739 - accuracy: 0.4591 - val_loss: 1.5839 - val_accuracy: 0.4750
# Epoch 49/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6170 - accuracy: 0.4741 - val_loss: 1.5530 - val_accuracy: 0.4875
# Epoch 50/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6865 - accuracy: 0.4526 - val_loss: 1.5643 - val_accuracy: 0.4875
# Epoch 51/1000
# 25/29 [========================>.....] - ETA: 0s - loss: 1.6518 - accuracy: 0.4500
# vall acc improved from 0.512499988079071 to 0.5249999761581421, vall loss improved from 1.5388044118881226 to 1.5388044118881226, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6553 - accuracy: 0.4483 - val_loss: 1.5388 - val_accuracy: 0.5250
# Epoch 52/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6362 - accuracy: 0.4483 - val_loss: 1.5290 - val_accuracy: 0.4750
# Epoch 53/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6689 - accuracy: 0.4224 - val_loss: 1.5221 - val_accuracy: 0.5125
# Epoch 54/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5745 - accuracy: 0.4935 - val_loss: 1.5319 - val_accuracy: 0.4750
# Epoch 55/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6413 - accuracy: 0.4418 - val_loss: 1.5157 - val_accuracy: 0.5125
# Epoch 56/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6168 - accuracy: 0.4828 - val_loss: 1.5110 - val_accuracy: 0.5250
# Epoch 57/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6290 - accuracy: 0.4655 - val_loss: 1.5295 - val_accuracy: 0.5000
# Epoch 58/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6009 - accuracy: 0.4353 - val_loss: 1.4904 - val_accuracy: 0.5125
# Epoch 59/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5707 - accuracy: 0.5065 - val_loss: 1.4914 - val_accuracy: 0.5250
# Epoch 60/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6071 - accuracy: 0.4440 - val_loss: 1.4943 - val_accuracy: 0.4875
# Epoch 61/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5618 - accuracy: 0.4720 - val_loss: 1.4812 - val_accuracy: 0.5000
# Epoch 62/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6051 - accuracy: 0.4547 - val_loss: 1.4753 - val_accuracy: 0.5250
# Epoch 63/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5973 - accuracy: 0.4806 - val_loss: 1.4658 - val_accuracy: 0.5250
# Epoch 64/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5247 - accuracy: 0.4849 - val_loss: 1.4757 - val_accuracy: 0.5250
# Epoch 65/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5778 - accuracy: 0.4504 - val_loss: 1.4605 - val_accuracy: 0.5125
# Epoch 66/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5746 - accuracy: 0.4828 - val_loss: 1.4529 - val_accuracy: 0.5250
# Epoch 67/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5642 - accuracy: 0.4763 - val_loss: 1.4526 - val_accuracy: 0.5250
# Epoch 68/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5413 - accuracy: 0.4957 - val_loss: 1.4537 - val_accuracy: 0.5250
# Epoch 69/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5285 - accuracy: 0.4892 - val_loss: 1.4311 - val_accuracy: 0.5250
# Epoch 70/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5393 - accuracy: 0.4935 - val_loss: 1.4313 - val_accuracy: 0.5125
# Epoch 71/1000
# 26/29 [=========================>....] - ETA: 0s - loss: 1.5472 - accuracy: 0.4928
# vall acc improved from 0.5249999761581421 to 0.550000011920929, vall loss improved from 1.4287388324737549 to 1.4287388324737549, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5430 - accuracy: 0.4828 - val_loss: 1.4287 - val_accuracy: 0.5500
# Epoch 72/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5184 - accuracy: 0.5237 - val_loss: 1.4176 - val_accuracy: 0.5250
# Epoch 73/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5285 - accuracy: 0.4634 - val_loss: 1.4242 - val_accuracy: 0.5000
# Epoch 74/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5232 - accuracy: 0.4806 - val_loss: 1.4122 - val_accuracy: 0.5250
# Epoch 75/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5089 - accuracy: 0.5022 - val_loss: 1.4108 - val_accuracy: 0.5375
# Epoch 76/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5473 - accuracy: 0.4871 - val_loss: 1.4127 - val_accuracy: 0.5500
# Epoch 77/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5005 - accuracy: 0.4978 - val_loss: 1.4163 - val_accuracy: 0.5375
# Epoch 78/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5046 - accuracy: 0.4806 - val_loss: 1.4029 - val_accuracy: 0.5375
# Epoch 79/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4859 - accuracy: 0.5043 - val_loss: 1.4045 - val_accuracy: 0.5500
# Epoch 80/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5048 - accuracy: 0.4784 - val_loss: 1.3877 - val_accuracy: 0.5125
# Epoch 81/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5001 - accuracy: 0.4914 - val_loss: 1.3839 - val_accuracy: 0.5500
# Epoch 82/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4543 - accuracy: 0.5302 - val_loss: 1.3906 - val_accuracy: 0.5250
# Epoch 83/1000
# 26/29 [=========================>....] - ETA: 0s - loss: 1.5398 - accuracy: 0.4904
# vall acc improved from 0.550000011920929 to 0.5625, vall loss improved from 1.3893883228302002 to 1.3893883228302002, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5421 - accuracy: 0.4806 - val_loss: 1.3894 - val_accuracy: 0.5625
# Epoch 84/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4494 - accuracy: 0.5172 - val_loss: 1.3838 - val_accuracy: 0.5625
# Epoch 85/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4604 - accuracy: 0.5194 - val_loss: 1.3713 - val_accuracy: 0.5250
# Epoch 86/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4990 - accuracy: 0.4784 - val_loss: 1.3755 - val_accuracy: 0.5625
# Epoch 87/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4528 - accuracy: 0.5280 - val_loss: 1.3692 - val_accuracy: 0.5000
# Epoch 88/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4673 - accuracy: 0.4806 - val_loss: 1.3610 - val_accuracy: 0.5625
# Epoch 89/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4869 - accuracy: 0.4892 - val_loss: 1.3667 - val_accuracy: 0.5375
# Epoch 90/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4287 - accuracy: 0.5409 - val_loss: 1.3570 - val_accuracy: 0.5500
# Epoch 91/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4777 - accuracy: 0.4849 - val_loss: 1.3483 - val_accuracy: 0.5625
# Epoch 92/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4578 - accuracy: 0.4871 - val_loss: 1.3634 - val_accuracy: 0.5625
# Epoch 93/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4530 - accuracy: 0.4914 - val_loss: 1.3625 - val_accuracy: 0.5625
# Epoch 94/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4279 - accuracy: 0.5259 - val_loss: 1.3445 - val_accuracy: 0.5500
# Epoch 95/1000
# 26/29 [=========================>....] - ETA: 0s - loss: 1.5060 - accuracy: 0.4808
# vall acc improved from 0.5625 to 0.5874999761581421, vall loss improved from 1.337010383605957 to 1.337010383605957, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4820 - accuracy: 0.4871 - val_loss: 1.3370 - val_accuracy: 0.5875
# Epoch 96/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4116 - accuracy: 0.5237 - val_loss: 1.3406 - val_accuracy: 0.5625
# Epoch 97/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4751 - accuracy: 0.4871 - val_loss: 1.3534 - val_accuracy: 0.5625
# Epoch 98/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4376 - accuracy: 0.4914 - val_loss: 1.3351 - val_accuracy: 0.5625
# Epoch 99/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4153 - accuracy: 0.4914 - val_loss: 1.3322 - val_accuracy: 0.5625
# Epoch 100/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4462 - accuracy: 0.5000 - val_loss: 1.3307 - val_accuracy: 0.5625
# Epoch 101/1000
# 25/29 [========================>.....] - ETA: 0s - loss: 1.4198 - accuracy: 0.5325
# vall acc improved from 0.5874999761581421 to 0.6000000238418579, vall loss improved from 1.3317264318466187 to 1.3317264318466187, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4452 - accuracy: 0.5108 - val_loss: 1.3317 - val_accuracy: 0.6000
# Epoch 102/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3760 - accuracy: 0.5323 - val_loss: 1.3311 - val_accuracy: 0.5625
# Epoch 103/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4537 - accuracy: 0.4957 - val_loss: 1.3233 - val_accuracy: 0.6000
# Epoch 104/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4193 - accuracy: 0.5366 - val_loss: 1.3185 - val_accuracy: 0.5500
# Epoch 105/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3988 - accuracy: 0.5129 - val_loss: 1.3159 - val_accuracy: 0.5750
# Epoch 106/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4255 - accuracy: 0.5065 - val_loss: 1.3274 - val_accuracy: 0.5750
# Epoch 107/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4424 - accuracy: 0.5065 - val_loss: 1.3123 - val_accuracy: 0.6000
# Epoch 108/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3451 - accuracy: 0.5517 - val_loss: 1.3176 - val_accuracy: 0.5750
# Epoch 109/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4447 - accuracy: 0.5000 - val_loss: 1.3012 - val_accuracy: 0.6000
# Epoch 110/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 1.4170 - accuracy: 0.5129 - val_loss: 1.3107 - val_accuracy: 0.5750
# Epoch 111/1000
# 24/29 [=======================>......] - ETA: 0s - loss: 1.4287 - accuracy: 0.4792
# vall acc improved from 0.6000000238418579 to 0.625, vall loss improved from 1.3010380268096924 to 1.3010380268096924, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4288 - accuracy: 0.4871 - val_loss: 1.3010 - val_accuracy: 0.6250
# Epoch 112/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3065 - accuracy: 0.5754 - val_loss: 1.3187 - val_accuracy: 0.5500
# Epoch 113/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4271 - accuracy: 0.5345 - val_loss: 1.2896 - val_accuracy: 0.6000
# Epoch 114/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3616 - accuracy: 0.5259 - val_loss: 1.2919 - val_accuracy: 0.6250
# Epoch 115/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3889 - accuracy: 0.5043 - val_loss: 1.3061 - val_accuracy: 0.5750
# Epoch 116/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4436 - accuracy: 0.5108 - val_loss: 1.2964 - val_accuracy: 0.5625
# Epoch 117/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3810 - accuracy: 0.5237 - val_loss: 1.2971 - val_accuracy: 0.6125
# Epoch 118/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4063 - accuracy: 0.5065 - val_loss: 1.2904 - val_accuracy: 0.5875
# Epoch 119/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3488 - accuracy: 0.5496 - val_loss: 1.2879 - val_accuracy: 0.5875
# Epoch 120/1000
# 26/29 [=========================>....] - ETA: 0s - loss: 1.4034 - accuracy: 0.5120
# vall acc improved from 0.625 to 0.637499988079071, vall loss improved from 1.2771975994110107 to 1.2771975994110107, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3993 - accuracy: 0.5237 - val_loss: 1.2772 - val_accuracy: 0.6375
# Epoch 121/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3716 - accuracy: 0.5259 - val_loss: 1.2877 - val_accuracy: 0.6000
# Epoch 122/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3515 - accuracy: 0.5539 - val_loss: 1.2808 - val_accuracy: 0.5750
# Epoch 123/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3876 - accuracy: 0.5453 - val_loss: 1.2810 - val_accuracy: 0.6000
# Epoch 124/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3657 - accuracy: 0.5237 - val_loss: 1.2824 - val_accuracy: 0.5625
# Epoch 125/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3821 - accuracy: 0.5151 - val_loss: 1.2767 - val_accuracy: 0.6250
# Epoch 126/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3976 - accuracy: 0.5022 - val_loss: 1.2748 - val_accuracy: 0.5875
# Epoch 127/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3603 - accuracy: 0.5539 - val_loss: 1.2750 - val_accuracy: 0.5875
# Epoch 128/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1
1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2897 - accuracy: 0.5366 - val_loss: 1.2240 - val_accuracy: 0.6375
# Epoch 160/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3430 - accuracy: 0.5409 - val_loss: 1.2322 - val_accuracy: 0.5875
# Epoch 161/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2960 - accuracy: 0.5409 - val_loss: 1.2333 - val_accuracy: 0.5875
# Epoch 162/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3092 - accuracy: 0.5754 - val_loss: 1.2269 - val_accuracy: 0.6250
# Epoch 163/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3313 - accuracy: 0.5366 - val_loss: 1.2181 - val_accuracy: 0.6375
# Epoch 164/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2819 - accuracy: 0.5517 - val_loss: 1.2549 - val_accuracy: 0.5625
# Epoch 165/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3372 - accuracy: 0.5323 - val_loss: 1.2183 - val_accuracy: 0.5750
# Epoch 166/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2396 - accuracy: 0.5819 - val_loss: 1.2128 - val_accuracy: 0.6250
# Epoch 167/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3216 - accuracy: 0.5474 - val_loss: 1.2239 - val_accuracy: 0.6250
# Epoch 168/1000
# 25/29 [========================>.....] - ETA: 0s - loss: 1.3407 - accuracy: 0.5300
# vall acc improved from 0.637499988079071 to 0.6499999761581421, vall loss improved from 1.2082115411758423 to 1.2082115411758423, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3327 - accuracy: 0.5237 - val_loss: 1.2082 - val_accuracy: 0.6500
# Epoch 169/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3094 - accuracy: 0.5539 - val_loss: 1.2269 - val_accuracy: 0.6000
# Epoch 170/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2893 - accuracy: 0.5539 - val_loss: 1.2225 - val_accuracy: 0.6000
# Epoch 171/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2779 - accuracy: 0.5560 - val_loss: 1.2229 - val_accuracy: 0.6000
# Epoch 172/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2790 - accuracy: 0.5237 - val_loss: 1.2282 - val_accuracy: 0.5875
# Epoch 173/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3055 - accuracy: 0.5345 - val_loss: 1.2193 - val_accuracy: 0.6250
# Epoch 174/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2934 - accuracy: 0.5690 - val_loss: 1.2002 - val_accuracy: 0.6375
# Epoch 175/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2968 - accuracy: 0.5237 - val_loss: 1.2188 - val_accuracy: 0.6125
# Epoch 176/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3040 - accuracy: 0.5517 - val_loss: 1.2056 - val_accuracy: 0.6500
# Epoch 177/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3617 - accuracy: 0.5409 - val_loss: 1.2105 - val_accuracy: 0.6375
# Epoch 178/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1683 - accuracy: 0.5647 - val_loss: 1.2183 - val_accuracy: 0.5875
# Epoch 179/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3366 - accuracy: 0.5474 - val_loss: 1.2117 - val_accuracy: 0.6375
# Epoch 180/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2576 - accuracy: 0.5797 - val_loss: 1.2178 - val_accuracy: 0.5750
# Epoch 181/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3048 - accuracy: 0.5172 - val_loss: 1.2017 - val_accuracy: 0.6125
# Epoch 182/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2778 - accuracy: 0.5647 - val_loss: 1.1982 - val_accuracy: 0.6125
# Epoch 183/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2933 - accuracy: 0.5431 - val_loss: 1.2048 - val_accuracy: 0.5875
# Epoch 184/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2874 - accuracy: 0.5453 - val_loss: 1.2095 - val_accuracy: 0.6000
# Epoch 185/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2541 - accuracy: 0.5517 - val_loss: 1.2050 - val_accuracy: 0.6250
# Epoch 186/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3040 - accuracy: 0.5323 - val_loss: 1.2149 - val_accuracy: 0.6000
# Epoch 187/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2780 - accuracy: 0.5431 - val_loss: 1.1936 - val_accuracy: 0.6375
# Epoch 188/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2365 - accuracy: 0.5797 - val_loss: 1.1869 - val_accuracy: 0.6500
# Epoch 189/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3205 - accuracy: 0.5323 - val_loss: 1.2168 - val_accuracy: 0.6000
# Epoch 190/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2644 - accuracy: 0.5668 - val_loss: 1.2033 - val_accuracy: 0.6000
# Epoch 191/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2891 - accuracy: 0.5280 - val_loss: 1.2069 - val_accuracy: 0.6125
# Epoch 192/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2871 - accuracy: 0.5453 - val_loss: 1.1892 - val_accuracy: 0.6250
# Epoch 193/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2438 - accuracy: 0.5754 - val_loss: 1.2064 - val_accuracy: 0.6000
# Epoch 194/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2530 - accuracy: 0.5496 - val_loss: 1.2124 - val_accuracy: 0.6125
# Epoch 195/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2532 - accuracy: 0.5474 - val_loss: 1.1907 - val_accuracy: 0.6375
# Epoch 196/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2761 - accuracy: 0.5517 - val_loss: 1.1885 - val_accuracy: 0.6375
# Epoch 197/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 1.2839 - accuracy: 0.5560 - val_loss: 1.1906 - val_accuracy: 0.6250
# Epoch 198/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2787 - accuracy: 0.5431 - val_loss: 1.1888 - val_accuracy: 0.6250
# Epoch 199/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2358 - accuracy: 0.5582 - val_loss: 1.1922 - val_accuracy: 0.6500
# Epoch 200/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3079 - accuracy: 0.5496 - val_loss: 1.1859 - val_accuracy: 0.6125
# Epoch 201/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2154 - accuracy: 0.5496 - val_loss: 1.1860 - val_accuracy: 0.6375
# Epoch 202/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2426 - accuracy: 0.5582 - val_loss: 1.1881 - val_accuracy: 0.6250
# Epoch 203/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2562 - accuracy: 0.5539 - val_loss: 1.1904 - val_accuracy: 0.6375
# Epoch 204/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2784 - accuracy: 0.5259 - val_loss: 1.1828 - val_accuracy: 0.6125
# Epoch 205/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2744 - accuracy: 0.5582 - val_loss: 1.1901 - val_accuracy: 0.6375
# Epoch 206/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2200 - accuracy: 0.5711 - val_loss: 1.1927 - val_accuracy: 0.6250
# Epoch 207/1000
# 23/29 [======================>.......] - ETA: 0s - loss: 1.2714 - accuracy: 0.5543
# vall acc improved from 0.6499999761581421 to 0.6625000238418579, vall loss improved from 1.178008794784546 to 1.178008794784546, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2429 - accuracy: 0.5733 - val_loss: 1.1780 - val_accuracy: 0.6625
# Epoch 208/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2840 - accuracy: 0.5474 - val_loss: 1.1918 - val_accuracy: 0.6125
# Epoch 209/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2420 - accuracy: 0.5625 - val_loss: 1.1867 - val_accuracy: 0.6375
# Epoch 210/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2414 - accuracy: 0.5366 - val_loss: 1.1826 - val_accuracy: 0.6125
# Epoch 211/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2675 - accuracy: 0.5668 - val_loss: 1.1934 - val_accuracy: 0.6000
# Epoch 212/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2477 - accuracy: 0.5647 - val_loss: 1.1791 - val_accuracy: 0.6375
# Epoch 213/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2532 - accuracy: 0.5366 - val_loss: 1.1894 - val_accuracy: 0.6250
# Epoch 214/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2446 - accuracy: 0.5647 - val_loss: 1.1826 - val_accuracy: 0.6375
# Epoch 215/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2587 - accuracy: 0.5216 - val_loss: 1.1762 - val_accuracy: 0.6000
# Epoch 216/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2452 - accuracy: 0.5496 - val_loss: 1.1824 - val_accuracy: 0.6250
# Epoch 217/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2194 - accuracy: 0.5991 - val_loss: 1.1743 - val_accuracy: 0.6250
# Epoch 218/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2494 - accuracy: 0.5560 - val_loss: 1.1781 - val_accuracy: 0.6375
# Epoch 219/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2383 - accuracy: 0.5345 - val_loss: 1.1787 - val_accuracy: 0.6250
# Epoch 220/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2443 - accuracy: 0.5496 - val_loss: 1.1742 - val_accuracy: 0.6250
# Epoch 221/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2070 - accuracy: 0.5668 - val_loss: 1.1820 - val_accuracy: 0.6625
# Epoch 222/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2728 - accuracy: 0.5409 - val_loss: 1.1667 - val_accuracy: 0.5875
# Epoch 223/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2568 - accuracy: 0.5539 - val_loss: 1.1652 - val_accuracy: 0.6375
# Epoch 224/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1974 - accuracy: 0.5841 - val_loss: 1.1736 - val_accuracy: 0.6000
# Epoch 225/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2100 - accuracy: 0.5841 - val_loss: 1.1805 - val_accuracy: 0.6250
# Epoch 226/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2762 - accuracy: 0.5453 - val_loss: 1.1576 - val_accuracy: 0.6500
# Epoch 227/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2456 - accuracy: 0.5560 - val_loss: 1.1635 - val_accuracy: 0.6375
# Epoch 228/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2137 - accuracy: 0.5797 - val_loss: 1.1588 - val_accuracy: 0.6250
# Epoch 229/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2634 - accuracy: 0.5323 - val_loss: 1.1863 - val_accuracy: 0.5875
# Epoch 230/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2174 - accuracy: 0.5733 - val_loss: 1.1611 - val_accuracy: 0.6375
# Epoch 231/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2435 - accuracy: 0.5690 - val_loss: 1.1707 - val_accuracy: 0.5750
# Epoch 232/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2290 - accuracy: 0.5711 - val_loss: 1.1665 - val_accuracy: 0.6500
# Epoch 233/1000
# 24/29 [=======================>......] - ETA: 0s - loss: 1.2206 - accuracy: 0.5469
# vall acc improved from 0.6625000238418579 to 0.675000011920929, vall loss improved from 1.1492433547973633 to 1.1492433547973633, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 4ms/step - loss: 1.2233 - accuracy: 0.5496 - val_loss: 1.1492 - val_accuracy: 0.6750
# Epoch 234/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2408 - accuracy: 0.5603 - val_loss: 1.1661 - val_accuracy: 0.6375
# Epoch 235/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1771 - accuracy: 0.5819 - val_loss: 1.1702 - val_accuracy: 0.6375
# Epoch 236/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2521 - accuracy: 0.5647 - val_loss: 1.1499 - val_accuracy: 0.6625
# Epoch 237/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2075 - accuracy: 0.5603 - val_loss: 1.1704 - val_accuracy: 0.6250
# Epoch 238/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2047 - accuracy: 0.5711 - val_loss: 1.1764 - val_accuracy: 0.6250
# Epoch 239/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2601 - accuracy: 0.5733 - val_loss: 1.1515 - val_accuracy: 0.6500
# Epoch 240/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2155 - accuracy: 0.5603 - val_loss: 1.1661 - val_accuracy: 0.6375
# Epoch 241/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1
1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2047 - accuracy: 0.5797 - val_loss: 1.1552 - val_accuracy: 0.6375
# Epoch 271/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2006 - accuracy: 0.5603 - val_loss: 1.1382 - val_accuracy: 0.6375
# Epoch 272/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1598 - accuracy: 0.5970 - val_loss: 1.1409 - val_accuracy: 0.6500
# Epoch 273/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2202 - accuracy: 0.5668 - val_loss: 1.1440 - val_accuracy: 0.6250
# Epoch 274/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1850 - accuracy: 0.5862 - val_loss: 1.1345 - val_accuracy: 0.6250
# Epoch 275/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2190 - accuracy: 0.5625 - val_loss: 1.1489 - val_accuracy: 0.6625
# Epoch 276/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1554 - accuracy: 0.5754 - val_loss: 1.1589 - val_accuracy: 0.6125
# Epoch 277/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2297 - accuracy: 0.5603 - val_loss: 1.1232 - val_accuracy: 0.6500
# Epoch 278/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1716 - accuracy: 0.5862 - val_loss: 1.1318 - val_accuracy: 0.6625
# Epoch 279/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2421 - accuracy: 0.5560 - val_loss: 1.1280 - val_accuracy: 0.6500
# Epoch 280/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 1.1220 - accuracy: 0.5884 - val_loss: 1.1378 - val_accuracy: 0.6250
# Epoch 281/1000
# 23/29 [======================>.......] - ETA: 0s - loss: 1.2020 - accuracy: 0.5951
# vall acc improved from 0.675000011920929 to 0.6875, vall loss improved from 1.1269580125808716 to 1.1269580125808716, saving model to best_model variable
# Model weights saved to disk
# 29/29 [==============================] - 0s 4ms/step - loss: 1.1756 - accuracy: 0.5927 - val_loss: 1.1270 - val_accuracy: 0.6875
# Epoch 282/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 1.1772 - accuracy: 0.5884 - val_loss: 1.1255 - val_accuracy: 0.6500
# Epoch 283/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2343 - accuracy: 0.5560 - val_loss: 1.1354 - val_accuracy: 0.6375
# Epoch 284/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1485 - accuracy: 0.5733 - val_loss: 1.1207 - val_accuracy: 0.6750
# Epoch 285/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1815 - accuracy: 0.5647 - val_loss: 1.1247 - val_accuracy: 0.6375
# Epoch 286/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1987 - accuracy: 0.5711 - val_loss: 1.1361 - val_accuracy: 0.6500
# Epoch 287/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 1.1105 - accuracy: 0.6034 - val_loss: 1.1113 - val_accuracy: 0.6750
# Epoch 288/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2330 - accuracy: 0.5754 - val_loss: 1.1406 - val_accuracy: 0.6375
# Epoch 289/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1570 - accuracy: 0.5754 - val_loss: 1.1173 - val_accuracy: 0.6500
# Epoch 290/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2242 - accuracy: 0.5474 - val_loss: 1.1090 - val_accuracy: 0.6625
# Epoch 291/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1404 - accuracy: 0.6013 - val_loss: 1.1404 - val_accuracy: 0.6250
# Epoch 292/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1696 - accuracy: 0.5776 - val_loss: 1.1348 - val_accuracy: 0.6375
# Epoch 293/1000
# ...
# Epoch 891/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8611 - accuracy: 0.6746 - val_loss: 0.9882 - val_accuracy: 0.6875
# Epoch 892/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 0.8489 - accuracy: 0.6832 - val_loss: 0.9868 - val_accuracy: 0.7000
# Epoch 893/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8627 - accuracy: 0.6875 - val_loss: 0.9929 - val_accuracy: 0.7250
# Epoch 894/1000
# 29/29 [==============================] - 0s 3ms/step - loss:
1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8488 - accuracy: 0.6875 - val_loss: 1.0073 - val_accuracy: 0.7125
# Epoch 967/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 0.7994 - accuracy: 0.7091 - val_loss: 1.0496 - val_accuracy: 0.6875
# Epoch 968/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8222 - accuracy: 0.6961 - val_loss: 1.0180 - val_accuracy: 0.7000
# Epoch 969/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8639 - accuracy: 0.6918 - val_loss: 1.0164 - val_accuracy: 0.7000
# Epoch 970/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.7869 - accuracy: 0.7091 - val_loss: 0.9712 - val_accuracy: 0.7125
# Epoch 971/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8240 - accuracy: 0.7177 - val_loss: 1.0338 - val_accuracy: 0.7125
# Epoch 972/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.7867 - accuracy: 0.7241 - val_loss: 0.9792 - val_accuracy: 0.7375
# Epoch 973/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8724 - accuracy: 0.6724 - val_loss: 0.9988 - val_accuracy: 0.7250
# Epoch 974/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8095 - accuracy: 0.6983 - val_loss: 0.9772 - val_accuracy: 0.7375
# Epoch 975/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8049 - accuracy: 0.7134 - val_loss: 0.9974 - val_accuracy: 0.7250
# Epoch 976/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8761 - accuracy: 0.6832 - val_loss: 0.9941 - val_accuracy: 0.7125
# Epoch 977/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.7592 - accuracy: 0.7091 - val_loss: 0.9914 - val_accuracy: 0.7250
# Epoch 978/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8749 - accuracy: 0.6703 - val_loss: 0.9950 - val_accuracy: 0.7250
# Epoch 979/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.7813 - accuracy: 0.7177 - val_loss: 0.9961 - val_accuracy: 0.7250
# Epoch 980/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8266 - accuracy: 0.6875 - val_loss: 0.9807 - val_accuracy: 0.7125
# Epoch 981/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8454 - accuracy: 0.7047 - val_loss: 1.0286 - val_accuracy: 0.7125
# Epoch 982/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 0.8222 - accuracy: 0.7026 - val_loss: 1.0052 - val_accuracy: 0.6875
# Epoch 983/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 0.8124 - accuracy: 0.7177 - val_loss: 0.9790 - val_accuracy: 0.7375
# Epoch 984/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 0.8225 - accuracy: 0.6789 - val_loss: 0.9884 - val_accuracy: 0.7250
# Epoch 985/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8343 - accuracy: 0.7047 - val_loss: 1.0206 - val_accuracy: 0.6875
# Epoch 986/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.7921 - accuracy: 0.6940 - val_loss: 0.9724 - val_accuracy: 0.6875
# Epoch 987/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8531 - accuracy: 0.6983 - val_loss: 1.0448 - val_accuracy: 0.7000
# Epoch 988/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.7825 - accuracy: 0.7177 - val_loss: 0.9675 - val_accuracy: 0.6875
# Epoch 989/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8662 - accuracy: 0.6724 - val_loss: 1.0032 - val_accuracy: 0.7125
# Epoch 990/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8044 - accuracy: 0.7026 - val_loss: 0.9932 - val_accuracy: 0.7250
# Epoch 991/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.7943 - accuracy: 0.7134 - val_loss: 0.9995 - val_accuracy: 0.7125
# Epoch 992/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8100 - accuracy: 0.7177 - val_loss: 0.9918 - val_accuracy: 0.7125
# Epoch 993/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8360 - accuracy: 0.6789 - val_loss: 1.0220 - val_accuracy: 0.6875
# Epoch 994/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8351 - accuracy: 0.6810 - val_loss: 0.9744 - val_accuracy: 0.7500
# Epoch 995/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 0.7775 - accuracy: 0.7306 - val_loss: 0.9780 - val_accuracy: 0.7125
# Epoch 996/1000
# 29/29 [==============================] - 0s 4ms/step - loss: 0.8172 - accuracy: 0.6897 - val_loss: 0.9808 - val_accuracy: 0.7500
# Epoch 997/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8222 - accuracy: 0.6897 - val_loss: 1.0174 - val_accuracy: 0.7000
# Epoch 998/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8139 - accuracy: 0.6983 - val_loss: 0.9812 - val_accuracy: 0.7375
# Epoch 999/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8474 - accuracy: 0.6961 - val_loss: 0.9965 - val_accuracy: 0.7375
# Epoch 1000/1000
# 29/29 [==============================] - 0s 3ms/step - loss: 0.7704 - accuracy: 0.7004 - val_loss: 0.9958 - val_accuracy: 0.7250
# Training done in 142.18864703178406s

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

plt.figure(figsize=(20,7.5))

plt.subplot(1, 2, 1)
plt.plot(epochs, accuracy, 'b', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Create the final model using the best estimator found

# %%
print("Testing final Artificial Neural Network model...")
ann_model.load_weights(ANN_MODEL_H5_WEIGHTS)
preds_valid = ann_model.predict(test_set)
preds_valid = np.argmax(preds_valid, axis=1)

# Metrics off the dataset
print(classification_report(Y_test, preds_valid, target_names=unique_label_names))
# Plot confusion matrix
ConfusionMatrixDisplay.from_predictions(Y_test, preds_valid, display_labels=unique_label_names)
plt.title("Artificial Neural Network Confusion matrix")
plt.show()
# plot_confusion_matrix(y_test_index, preds_valid_id, classes=unique_label_names, title='Support Vector Machine Confusion matrix')
# Out:
# Testing final Artificial Neural Network model...
#               precision    recall  f1-score   support
#
#        blues       0.70      0.76      0.73        21
#    classical       0.95      0.90      0.92        20
#      country       0.70      0.70      0.70        20
#        disco       0.35      0.55      0.43        20
#       hiphop       0.60      0.30      0.40        20
#         jazz       0.74      0.70      0.72        20
#        metal       0.79      0.75      0.77        20
#          pop       0.68      0.75      0.71        20
#       reggae       0.75      0.75      0.75        20
#         rock       0.28      0.25      0.26        20
#
#     accuracy                           0.64       201
#    macro avg       0.65      0.64      0.64       201
# weighted avg       0.65      0.64      0.64       201

# %% [markdown]
# ### Export model to csv file

# %%
 weights_and_biases = ann_model.get_weights()
 number_of_layers = len(weights_and_biases)/2

for i in range(0, len(weights_and_biases), 2):
  # Weights i
  # bias i+1
  CSV_HEADER = ["bias"] + list("weight{}".format(ni) for ni in range(len(weights_and_biases[i])))

  neuron_weights_and_biases = np.zeros((len(weights_and_biases[i+1]), len(weights_and_biases[i])+1))
  # print(neuron_weights_and_biases.shape)
  for bi in range(len(weights_and_biases[i+1])):
    neuron_weights_and_biases[bi, 0] = weights_and_biases[i+1][bi]
    for ni in range(len(weights_and_biases[i])):
      neuron_weights_and_biases[bi, ni+1] = weights_and_biases[i][ni, bi]

  # print(neuron_weights_and_biases[0])
  if i == len(weights_and_biases)/2 :
    ann_df = pd.DataFrame(neuron_weights_and_biases, columns=CSV_HEADER)
    ann_df["class"] = unique_label_names
    ann_df["class"] = ann_df["class"].astype(str)
    ann_df[CSV_HEADER[:]] = ann_df[CSV_HEADER[:]].astype(float)
  else:
    ann_df = pd.DataFrame(neuron_weights_and_biases, columns=CSV_HEADER)
    ann_df = ann_df.astype(float)

  csv_file = os.path.join(ANN_MODEL_CSV_FOLDER, "hidden_layer_{}.csv".format(int(i/2+1)))
  print("CSV file path: {}".format(csv_file))
  print("CSV file header: {}".format(CSV_HEADER))

  pd.DataFrame([CSV_HEADER]).to_csv(csv_file, mode='w', index=False, header=False, quoting=csv.QUOTE_NONE)
  ann_df.to_csv(csv_file, mode='a', index=False, header=False, quoting=csv.QUOTE_NONNUMERIC)
# Out:
# CSV file path: ./artificial_neural_network_mfcc/hidden_layer_1.csv
# CSV file header: ['bias', 'weight0', 'weight1', 'weight2', 'weight3', 'weight4', 'weight5', 'weight6', 'weight7', 'weight8', 'weight9', 'weight10', 'weight11', 'weight12', 'weight13', 'weight14', 'weight15', 'weight16', 'weight17', 'weight18', 'weight19', 'weight20', 'weight21', 'weight22', 'weight23', 'weight24', 'weight25', 'weight26', 'weight27', 'weight28', 'weight29', 'weight30', 'weight31', 'weight32', 'weight33', 'weight34', 'weight35', 'weight36', 'weight37', 'weight38', 'weight39', 'weight40', 'weight41']
# CSV file path: ./artificial_neural_network_mfcc/hidden_layer_2.csv
# CSV file header: ['bias', 'weight0', 'weight1', 'weight2', 'weight3', 'weight4', 'weight5', 'weight6', 'weight7', 'weight8', 'weight9', 'weight10', 'weight11', 'weight12', 'weight13', 'weight14', 'weight15', 'weight16', 'weight17', 'weight18', 'weight19', 'weight20', 'weight21', 'weight22', 'weight23', 'weight24', 'weight25', 'weight26', 'weight27']

# %% [markdown]
# ### Export model to h5 tensorflow file

# %%
# Save model description
model_json = ann_model.to_json()
with open(ANN_MODEL_JSON, "w") as json_file:
     json_file.write(model_json)
print("Model description saved to disk")

# Save model
ann_model.save(ANN_MODEL_H5)
print("Model saved to disk")

# Save model weights
ann_model.save_weights(ANN_MODEL_H5_WEIGHTS)
print("Model weights saved to disk")

# Fit history saving
with open(ANN_MODEL_HISTORY, 'wb') as file_pi:
     pickle.dump(history.history, file_pi)
print("Model history saved to disk")
# Out:
# Model description saved to disk
# Model saved to disk
# Model weights saved to disk
# Model history saved to disk

# %% [markdown]
# ### Cross validation to search for the best layer number and size

# %%
def build_ann_model(nfeatures, nlayer1, nlayer2, noutput, dropout): 
    model = keras.Sequential()
    model.add(Dense(input_shape=(nfeatures,), units=nlayer1, activation='relu', name="input"))
    model.add(Dropout(dropout, name="dropout_1"))
    if nlayer2 != 0:
      model.add(Dense(units=nlayer2, activation='relu', name="dense_1"))
      model.add(Dropout(dropout, name="dropout_2"))
    model.add(Dense(units=noutput, activation="softmax", name="output"))

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="sparse_categorical_crossentropy", metrics= ['accuracy'])
    return model

# Use early stoping to stop the learning once the mode lperformances stop improving
early_stop = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=40, verbose=1, mode='auto')
# model_cp = ModelCheckpoint(SVM_MODEL_H5_WEIGHTS, monitor='val_loss',  verbose=1, save_best_only=True, save_weights_only=True, mode='auto')
# Save the best model observed during training for later use

best_val_acc = 0
best_val_loss = sys.float_info.max 

def save_model(epoch, logs):
    global best_val_acc, best_val_loss
    val_acc = logs['val_accuracy']
    val_loss = logs['val_loss']
    if val_acc > best_val_acc and val_loss < best_val_loss :
        best_val_loss=val_loss
        print("vall acc improved from {} to {}, vall loss improved from {} to {}, saving model to best_model variable".format(best_val_acc, val_acc, best_val_loss, val_loss))
        best_val_acc = val_acc
        tmp_model.save_weights('tmp_'+ANN_MODEL_H5_WEIGHTS)
        print("Model weights saved to disk")

# %%
from datetime import datetime

layer_1_list = list(range(int(input_shape/2), input_shape, 1))
layer_2_list = list(range(int(input_shape/4), input_shape, 10))
layer_2_list.append(0)

start_time = datetime.now()

# Hyperparameters tuning using cross-validation with grid search
print("Starting cross-validation hyperparameters tuning...")
model_scores = {}
model_index = 0
hyperparameters_size = len(layer_1_list)*len(layer_2_list)
progress = 0
print("======= {:0.2f}% ({}/{}) done =======".format(progress*100, progress*hyperparameters_size, hyperparameters_size))

for i in range(len(layer_1_list)):
    layer_1 = layer_1_list[i]
    for j in range(len(layer_2_list)):
        layer_2 = layer_2_list[j]
        model_index += 1
        score_sum = 0

        # Compile model
        tmp_model = build_ann_model(input_shape, layer_1, layer_2, input_shape, 0.2)
        # Use early stoping to stop the learning once the mode lperformances stop improving
        early_stop = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=40, verbose=1, mode='auto')
        # model_cp = ModelCheckpoint(SVM_MODEL_H5_WEIGHTS, monitor='val_loss',  verbose=1, save_best_only=True, save_weights_only=True, mode='auto')
        # Save the best model observed during training for later use

        global best_val_acc, best_val_loss
        best_val_acc = 0
        best_val_loss = sys.float_info.max 

        # Learnign stage
        history = tmp_model.fit(train_set,
                            validation_data=valid_set,
                            epochs=1000,
                            verbose=0,
                            steps_per_epoch=int(0.75 * dataset_size / batch_size),
                            validation_steps=int(0.15 * dataset_size / batch_size),
                            callbacks=[early_stop])
      
        progress = (i * len(layer_1_list) + j + 1) / (hyperparameters_size)
        model_scores["{}:{}".format(layer_1, layer_2)]= {'val_accuracy':best_val_acc,'val_loss': best_val_loss}
        print("--------- Results: (layer_1: {}, layer_2: {}, val_accuracy: {:0.2f}%,  val_loss: {:0.2f}%)".format(layer_1, layer_2, best_val_acc, best_val_loss))
        print("======= {:0.2f}% ({}/{}) done =======".format(progress*100, progress*hyperparameters_size, hyperparameters_size))

stop_time = datetime.now()
print("Elapsed time: {}".format(stop_time - start_time))

# %%
biggest_acc = {'none':0}
smallest_loss = {'none':sys.float_info.max}
for k,v in model_scores.items():
  if v['val_accuracy'] >= list(biggest_acc.values())[0]:
    biggest_acc = {k:v['val_accuracy']}
  if v['val_loss'] >= list(smallest_loss.values())[0]:
    smallest_loss = {k:v['val_loss']}

print("best accuracy (layer1_layer2): {}".format(biggest_acc))
print("best loss (layer1_layer2): {}".format(smallest_loss))
