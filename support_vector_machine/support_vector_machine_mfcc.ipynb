# %%
import os
import graphviz
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from time import time
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split, GridSearchCV

from utils import svm_to_csv

SVM_MODEL_CSV = os.path.join("./", "support_vector_machine_mfcc.csv")

# %% [markdown]
# ### Extract the dataset from the .au csv files

# %%
print("Extracting dataset training set...")
dataset = '../../datasets/music_features_mfcc_train.csv'
musics_df = pd.read_csv(dataset, header=0)
# Get all style values
Y_train = musics_df["style"].values
# Get all features names
features_name = musics_df.columns.values[:-2]
# Get all features values
# musics_df = musics_df.drop('style', axis=1)
# musics_df = musics_df.drop('file_name', axis=1)
# X = musics_df.values
X_train = musics_df.loc[:, ~musics_df.columns.isin(['style', 'file_name'])].values
unique_label_names = np.unique(Y_train)

print("File contains {} unique_label_names: ".format(len(unique_label_names), unique_label_names))
print("File contains {} lines of {} data ".format(X_train.shape[0], X_train.shape[1]))

print("Extracting dataset testing set...")
dataset = '../../datasets/music_features_mfcc_test.csv'
musics_df = pd.read_csv(dataset, header=0)
# Get all style values
Y_test = musics_df["style"].values
# Get all features names
features_name = musics_df.columns.values[:-2]
# Get all features values
# musics_df = musics_df.drop('style', axis=1)
# musics_df = musics_df.drop('file_name', axis=1)
# X = musics_df.values
X_test = musics_df.loc[:, ~musics_df.columns.isin(['style', 'file_name'])].values
unique_label_names = np.unique(Y_test)

print("File contains {} unique_label_names: ".format(len(unique_label_names), unique_label_names))
print("File contains {} lines of {} data ".format(X_test.shape[0], X_test.shape[1]))
# Out:
# Extracting dataset training set...
# File contains 10 unique_label_names:
# File contains 799 lines of 42 data
# Extracting dataset testing set...
# File contains 10 unique_label_names:
# File contains 201 lines of 42 data

# %% [markdown]
# # Support Vector Machine (using linear kernel)

# %% [markdown]
# ### Optimize model using Grid search and cross validation

# %%
print("Creating Support Vector Machine model...")
svm_model = SVC()

print("Training Support Vector Machine model using grid search and cross validation...")
C_list = list(np.arange(0.1, 75, 0.05))
param_grid = dict(kernel=['linear'], C=C_list)

svm_model = GridSearchCV(svm_model, param_grid, cv=5, verbose=2, n_jobs=os.cpu_count()-1)
t_start = time()
svm_model.fit(X_train, Y_train)
print("Training done in {}s".format(time()-t_start))

svm_model_best_estimator = svm_model.best_estimator_
print("Support Vector Machine best estimator found using grid search: {}".format(svm_model_best_estimator))
# Out:
# Creating Support Vector Machine model...
# Training Support Vector Machine model using grid search and cross validation...
# Fitting 5 folds for each of 1498 candidates, totalling 7490 fits
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.15000000000000002, kernel=linear; total time=   0.2s[CV] END ...............................C=0.1, kernel=linear; total time=   0.1s
#
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.1s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.2s
# [CV] END ...............C=0.15000000000000002, kernel=linear; total time=   0.1s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.15000000000000002, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.15000000000000002, kernel=linear; total time=   0.1s[CV] END ...............C=0.20000000000000004, kernel=linear; total time=   0.1s
#
# [CV] END ...............C=0.20000000000000004, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.20000000000000004, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.20000000000000004, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.25000000000000006, kernel=linear; total time=   0.1s[CV] END ...............C=0.25000000000000006, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.25000000000000006, kernel=linear; total time=   0.1s[CV] END ...............C=0.20000000000000004, kernel=linear; total time=   0.1s
#
#
# [CV] END ...............C=0.30000000000000004, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.25000000000000006, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.30000000000000004, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.30000000000000004, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.25000000000000006, kernel=linear; total time=   0.2s[CV] END ...............C=0.30000000000000004, kernel=linear; total time=   0.1s
#
# [CV] END ...............C=0.15000000000000002, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.30000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=0.3500000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=0.3500000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=0.3500000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=0.3500000000000001, kernel=linear; total time=   0.1s[CV] END ................C=0.3500000000000001, kernel=linear; total time=   0.1s
#
# [CV] END ...............C=0.40000000000000013, kernel=linear; total time=   0.1s[CV] END ...............C=0.40000000000000013, kernel=linear; total time=   0.1s
#
# [CV] END ...............C=0.40000000000000013, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.40000000000000013, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.45000000000000007, kernel=linear; total time=   0.1s[CV] END ...............C=0.40000000000000013, kernel=linear; total time=   0.1s
# [CV] END ...............C=0.45000000000000007, kernel=linear; total time=   0.1s
#
# [CV] END ...............C=0.45000000000000007, kernel=linear; total time=   0.1s
# [CV] END ................C=0.5000000000000001, kernel=linear; total time=   0.1s[CV] END ...............C=0.45000000000000007, kernel=linear; total time=   0.1s
#
# [CV] END ...............C=0.45000000000000007, kernel=linear; total time=   0.1s
# [CV] END ................C=0.5000000000000001, kernel=linear; total time=   0.1s[CV] END ................C=0.5000000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=0.5000000000000001, kernel=linear; total time=   0.1s
#
# [CV] END ................C=0.5000000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=0.5500000000000002, kernel=linear; total time=   0.1s[CV] END ................C=0.5500000000000002, kernel=linear; total time=   0.1s
#
# [CV] END ................C=0.5500000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.5500000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.5500000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.6000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.6000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.6500000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=0.6000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.6000000000000002, kernel=linear; total time=   0.1s[CV] END ................C=0.6500000000000001, kernel=linear; total time=   0.0s
# [CV] END ................C=0.6000000000000002, kernel=linear; total time=   0.1s
#
# [CV] END ................C=0.6500000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=0.6500000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=0.7000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.7000000000000002, kernel=linear; total time=   0.1s[CV] END ................C=0.7000000000000002, kernel=linear; total time=   0.1s
#
# [CV] END ................C=0.6500000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=0.7000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.7500000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.7000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.7500000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.7500000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.7500000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.7500000000000002, kernel=linear; total time=   0.1s[CV] END ................C=0.8000000000000002, kernel=linear; total time=   0.1s
#
# [CV] END ................C=0.8000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.8500000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.8000000000000002, kernel=linear; total time=   0.1s[CV] END ................C=0.8500000000000002, kernel=linear; total time=   0.1s
#
# [CV] END ................C=0.9000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.8500000000000002, kernel=linear; total time=   0.0s
# [CV] END ................C=0.8000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.8000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.8500000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.8500000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.9000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.9000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.9000000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=0.9500000000000003, kernel=linear; total time=   0.1s
# [CV] END ................C=0.9500000000000003, kernel=linear; total time=   0.1s
# [CV] END ................C=1.0000000000000004, kernel=linear; total time=   0.1s[CV] END ................C=0.9500000000000003, kernel=linear; total time=   0.1s
# [CV] END ................C=1.0000000000000004, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.0000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=0.9000000000000002, kernel=linear; total time=   0.1s[CV] END ................C=0.9500000000000003, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.0000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.0500000000000003, kernel=linear; total time=   0.1s
# [CV] END ................C=1.0500000000000003, kernel=linear; total time=   0.1s
# [CV] END ................C=0.9500000000000003, kernel=linear; total time=   0.1s
# [CV] END ................C=1.1000000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.0000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.0500000000000003, kernel=linear; total time=   0.1s
# [CV] END ................C=1.2000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.1500000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.0500000000000003, kernel=linear; total time=   0.1s
# [CV] END ................C=1.2000000000000004, kernel=linear; total time=   0.1s[CV] END ................C=1.1000000000000005, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.2000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.2500000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.0500000000000003, kernel=linear; total time=   0.1s
# [CV] END ................C=1.1500000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.3000000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.1000000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.2500000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.2500000000000004, kernel=linear; total time=   0.1s[CV] END ................C=1.2000000000000004, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.1000000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.1500000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.1500000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.3000000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.3000000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.2000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.2500000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.1000000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.3000000000000005, kernel=linear; total time=   0.1s[CV] END ................C=1.3500000000000005, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.1500000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.4000000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=1.2500000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.3000000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.3500000000000005, kernel=linear; total time=   0.1s[CV] END ................C=1.3500000000000005, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.4500000000000006, kernel=linear; total time=   0.1s[CV] END ................C=1.4000000000000006, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.4000000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=1.5000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.6000000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.3500000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.5500000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.4500000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=1.4000000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=1.4500000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=1.5000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.6000000000000005, kernel=linear; total time=   0.1s[CV] END ................C=1.3500000000000005, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.5500000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.5000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.4000000000000006, kernel=linear; total time=   0.1s[CV] END ................C=1.4500000000000006, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.5000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.6000000000000005, kernel=linear; total time=   0.1s[CV] END ................C=1.6000000000000005, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.5500000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.5000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.4500000000000006, kernel=linear; total time=   0.1s[CV] END ................C=1.6500000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=1.5500000000000005, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.6000000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.7000000000000006, kernel=linear; total time=   0.0s
# [CV] END ................C=1.6500000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=1.5500000000000005, kernel=linear; total time=   0.1s
# [CV] END ................C=1.7000000000000006, kernel=linear; total time=   0.1s[CV] END ................C=1.6500000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=1.8000000000000007, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.7500000000000007, kernel=linear; total time=   0.1s
# [CV] END ................C=1.8000000000000007, kernel=linear; total time=   0.1s
# [CV] END ................C=1.6500000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=1.8000000000000007, kernel=linear; total time=   0.1s[CV] END ................C=1.7000000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=1.8500000000000008, kernel=linear; total time=   0.1s
# [CV] END ................C=1.7000000000000006, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.8500000000000008, kernel=linear; total time=   0.1s[CV] END ................C=1.7500000000000007, kernel=linear; total time=   0.1s
# [CV] END ................C=1.6500000000000006, kernel=linear; total time=   0.1s[CV] END ................C=1.7500000000000007, kernel=linear; total time=   0.0s
#
#
# [CV] END ................C=1.8000000000000007, kernel=linear; total time=   0.1s
# [CV] END ................C=1.7000000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=1.9500000000000006, kernel=linear; total time=   0.0s[CV] END ................C=1.8500000000000008, kernel=linear; total time=   0.1s
# [CV] END ................C=1.7500000000000007, kernel=linear; total time=   0.1s
# [CV] END ................C=1.8500000000000008, kernel=linear; total time=   0.1s
# [CV] END ................C=1.9000000000000008, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.8000000000000007, kernel=linear; total time=   0.1s
# [CV] END ................C=1.9500000000000006, kernel=linear; total time=   0.1s[CV] END ................C=1.7500000000000007, kernel=linear; total time=   0.1s
# [CV] END ................C=1.9000000000000008, kernel=linear; total time=   0.1s
# [CV] END ................C=2.0000000000000004, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.8500000000000008, kernel=linear; total time=   0.1s
# [CV] END ................C=1.9000000000000008, kernel=linear; total time=   0.1s
# [CV] END ................C=2.0000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.9500000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=1.9000000000000008, kernel=linear; total time=   0.1s
# [CV] END ................C=2.0500000000000007, kernel=linear; total time=   0.1s
# [CV] END ................C=2.0000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=1.9000000000000008, kernel=linear; total time=   0.1s
# [CV] END ................C=2.0500000000000007, kernel=linear; total time=   0.0s
# [CV] END .................C=2.100000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=2.0500000000000007, kernel=linear; total time=   0.1s[CV] END .................C=2.150000000000001, kernel=linear; total time=   0.1s
#
# [CV] END ................C=1.9500000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=2.0000000000000004, kernel=linear; total time=   0.1s[CV] END ................C=1.9500000000000006, kernel=linear; total time=   0.1s
#
# [CV] END .................C=2.100000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=2.0500000000000007, kernel=linear; total time=   0.1s[CV] END .................C=2.100000000000001, kernel=linear; total time=   0.1s[CV] END .................C=2.150000000000001, kernel=linear; total time=   0.1s
#
#
# [CV] END ................C=2.2000000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=2.0000000000000004, kernel=linear; total time=   0.1s
# [CV] END ................C=2.2000000000000006, kernel=linear; total time=   0.1s
# [CV] END .................C=2.150000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.100000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.100000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=2.0500000000000007, kernel=linear; total time=   0.1s[CV] END .................C=2.250000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.150000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.250000000000001, kernel=linear; total time=   0.1s
#
# [CV] END ................C=2.2000000000000006, kernel=linear; total time=   0.1s
# [CV] END ................C=2.3000000000000007, kernel=linear; total time=   0.1s
# [CV] END .................C=2.150000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.250000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.400000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=2.2000000000000006, kernel=linear; total time=   0.1s[CV] END .................C=2.250000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=2.350000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=2.3000000000000007, kernel=linear; total time=   0.1s
# [CV] END .................C=2.400000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.400000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.250000000000001, kernel=linear; total time=   0.1s[CV] END ................C=2.3000000000000007, kernel=linear; total time=   0.1s
#
# [CV] END .................C=2.350000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=2.2000000000000006, kernel=linear; total time=   0.1s
# [CV] END .................C=2.400000000000001, kernel=linear; total time=   0.0s
# [CV] END ................C=2.3000000000000007, kernel=linear; total time=   0.1s
# [CV] END .................C=2.400000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=2.450000000000001, kernel=linear; total time=   0.1s[CV] END .................C=2.450000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=2.3000000000000007, kernel=linear; total time=   0.1s
# [CV] END .................C=2.350000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=2.500000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=2.5500000000000007, kernel=linear; total time=   0.0s
# [CV] END .................C=2.350000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.600000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.350000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=2.5500000000000007, kernel=linear; total time=   0.1s[CV] END .................C=2.500000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=2.450000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.600000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.600000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.450000000000001, kernel=linear; total time=   0.2s
# [CV] END ................C=2.5500000000000007, kernel=linear; total time=   0.1s
# [CV] END .................C=2.500000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.650000000000001, kernel=linear; total time=   0.1s[CV] END .................C=2.500000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.600000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=2.5500000000000007, kernel=linear; total time=   0.1s[CV] END .................C=2.650000000000001, kernel=linear; total time=   0.1s
#
#
# [CV] END .................C=2.450000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=2.5500000000000007, kernel=linear; total time=   0.1s[CV] END .................C=2.500000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.650000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=2.650000000000001, kernel=linear; total time=   0.1s[CV] END .................C=2.700000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.600000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=2.750000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.700000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.800000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.800000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.700000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.650000000000001, kernel=linear; total time=   0.1s[CV] END .................C=2.750000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=2.850000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.850000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.700000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.800000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.850000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=2.700000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.750000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.900000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.850000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.900000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.800000000000001, kernel=linear; total time=   0.1s[CV] END .................C=2.950000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=2.750000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.750000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.900000000000001, kernel=linear; total time=   0.1s[CV] END .................C=2.900000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=2.850000000000001, kernel=linear; total time=   0.1s[CV] END .................C=3.000000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=2.950000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.800000000000001, kernel=linear; total time=   0.1s[CV] END .................C=3.000000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=3.050000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.000000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.900000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.100000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.050000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.950000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.000000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.050000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.1500000000000012, kernel=linear; total time=   0.1s[CV] END .................C=3.050000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=2.950000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.000000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=2.950000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.100000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.100000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=3.050000000000001, kernel=linear; total time=   0.0s
# [CV] END ................C=3.1500000000000012, kernel=linear; total time=   0.1s
# [CV] END .................C=3.300000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=3.100000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.200000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.2500000000000013, kernel=linear; total time=   0.1s
# [CV] END .................C=3.100000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.200000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.2500000000000013, kernel=linear; total time=   0.0s
# [CV] END ................C=3.2500000000000013, kernel=linear; total time=   0.1s
# [CV] END .................C=3.300000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.1500000000000012, kernel=linear; total time=   0.1s[CV] END ................C=3.1500000000000012, kernel=linear; total time=   0.1s
#
# [CV] END ................C=3.2500000000000013, kernel=linear; total time=   0.0s
# [CV] END .................C=3.300000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=3.300000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.350000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.200000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.2500000000000013, kernel=linear; total time=   0.1s
# [CV] END .................C=3.350000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.1500000000000012, kernel=linear; total time=   0.1s
# [CV] END ................C=3.4000000000000012, kernel=linear; total time=   0.1s
# [CV] END .................C=3.300000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.450000000000001, kernel=linear; total time=   0.0s
# [CV] END ................C=3.4000000000000012, kernel=linear; total time=   0.1s
# [CV] END ................C=3.4000000000000012, kernel=linear; total time=   0.1s[CV] END .................C=3.350000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.200000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.450000000000001, kernel=linear; total time=   0.0s
#
# [CV] END .................C=3.450000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.550000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.5000000000000013, kernel=linear; total time=   0.1s
# [CV] END ................C=3.5000000000000013, kernel=linear; total time=   0.0s[CV] END .................C=3.450000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=3.200000000000001, kernel=linear; total time=   0.1s[CV] END .................C=3.350000000000001, kernel=linear; total time=   0.1s[CV] END ................C=3.4000000000000012, kernel=linear; total time=   0.1s
#
#
# [CV] END .................C=3.550000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.5000000000000013, kernel=linear; total time=   0.1s
# [CV] END .................C=3.450000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.5000000000000013, kernel=linear; total time=   0.1s
# [CV] END ................C=3.4000000000000012, kernel=linear; total time=   0.1s[CV] END .................C=3.350000000000001, kernel=linear; total time=   0.1s
#
# [CV] END ................C=3.6000000000000014, kernel=linear; total time=   0.1s
# [CV] END ................C=3.6000000000000014, kernel=linear; total time=   0.1s[CV] END .................C=3.550000000000001, kernel=linear; total time=   0.1s
#
# [CV] END ................C=3.6500000000000012, kernel=linear; total time=   0.1s[CV] END ................C=3.5000000000000013, kernel=linear; total time=   0.1s
#
# [CV] END ................C=3.7000000000000015, kernel=linear; total time=   0.1s
# [CV] END ................C=3.7500000000000013, kernel=linear; total time=   0.1s
# [CV] END ................C=3.6000000000000014, kernel=linear; total time=   0.1s[CV] END ................C=3.6500000000000012, kernel=linear; total time=   0.1s
# [CV] END .................C=3.550000000000001, kernel=linear; total time=   0.1s
#
# [CV] END ................C=3.6500000000000012, kernel=linear; total time=   0.1s
# [CV] END .................C=3.550000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.7000000000000015, kernel=linear; total time=   0.1s
# [CV] END ................C=3.7500000000000013, kernel=linear; total time=   0.1s
# [CV] END ................C=3.6500000000000012, kernel=linear; total time=   0.1s[CV] END ................C=3.7000000000000015, kernel=linear; total time=   0.1s
# [CV] END ................C=3.6000000000000014, kernel=linear; total time=   0.1s
# [CV] END .................C=3.800000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=3.800000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.7000000000000015, kernel=linear; total time=   0.1s
#
# [CV] END ................C=3.7500000000000013, kernel=linear; total time=   0.1s
# [CV] END ................C=3.6500000000000012, kernel=linear; total time=   0.1s
# [CV] END ................C=3.7000000000000015, kernel=linear; total time=   0.1s
# [CV] END ................C=3.8500000000000014, kernel=linear; total time=   0.1s
# [CV] END ................C=3.6000000000000014, kernel=linear; total time=   0.1s
# [CV] END ................C=3.7500000000000013, kernel=linear; total time=   0.1s
# [CV] END .................C=3.800000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.7500000000000013, kernel=linear; total time=   0.1s
# [CV] END ................C=3.8500000000000014, kernel=linear; total time=   0.1s[CV] END ................C=3.9000000000000012, kernel=linear; total time=   0.1s
# [CV] END ................C=3.9500000000000015, kernel=linear; total time=   0.1s
#
# [CV] END ................C=3.8500000000000014, kernel=linear; total time=   0.1s
# [CV] END .................C=4.000000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.9000000000000012, kernel=linear; total time=   0.1s[CV] END ................C=3.9500000000000015, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.000000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.8500000000000014, kernel=linear; total time=   0.1s[CV] END .................C=3.800000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.8500000000000014, kernel=linear; total time=   0.1s
#
# [CV] END ................C=3.9500000000000015, kernel=linear; total time=   0.1s
# [CV] END .................C=4.000000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.050000000000002, kernel=linear; total time=   0.1s[CV] END .................C=3.800000000000001, kernel=linear; total time=   0.0s
# [CV] END ................C=3.9000000000000012, kernel=linear; total time=   0.1s
#
# [CV] END ................C=3.9000000000000012, kernel=linear; total time=   0.1s
# [CV] END .................C=4.100000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=4.050000000000002, kernel=linear; total time=   0.1s
# [CV] END ................C=3.9500000000000015, kernel=linear; total time=   0.1s
# [CV] END .................C=4.000000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.9500000000000015, kernel=linear; total time=   0.1s[CV] END .................C=4.050000000000002, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.050000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=4.100000000000001, kernel=linear; total time=   0.1s
# [CV] END ................C=3.9000000000000012, kernel=linear; total time=   0.1s
# [CV] END .................C=4.000000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.200000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.150000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.050000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=4.100000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.200000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.100000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.200000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.300000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.100000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.150000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.250000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.250000000000001, kernel=linear; total time=   0.0s
#
# [CV] END .................C=4.150000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.200000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.300000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.250000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=4.350000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.250000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.150000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.400000000000001, kernel=linear; total time=   0.0s
#
# [CV] END .................C=4.200000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.300000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.250000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.350000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.150000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.300000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.400000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.350000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.400000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.450000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.350000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.300000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.450000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.550000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.400000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.350000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.450000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.500000000000001, kernel=linear; total time=   0.1s
#
#
# [CV] END .................C=4.600000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.450000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.400000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.550000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.600000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.500000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.600000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.450000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.500000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.650000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.550000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.650000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.500000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.700000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.600000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.650000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.550000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.650000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.500000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.600000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.700000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.550000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.700000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.750000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.650000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.700000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.800000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=4.800000000000002, kernel=linear; total time=   0.1s[CV] END .................C=4.750000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.700000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.850000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.900000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.750000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.800000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=4.750000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.900000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.950000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.850000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.850000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.000000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.800000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=4.750000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.950000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.900000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.900000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.850000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.000000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.000000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.800000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=4.950000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.950000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=4.900000000000001, kernel=linear; total time=   0.1s[CV] END .................C=4.850000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.000000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=4.950000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.050000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.050000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.200000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=5.100000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.150000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.000000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.200000000000001, kernel=linear; total time=   0.1s[CV] END .................C=5.150000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=5.100000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.050000000000002, kernel=linear; total time=   0.1s[CV] END .................C=5.050000000000002, kernel=linear; total time=   0.1s
#
#
# [CV] END .................C=5.200000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.250000000000002, kernel=linear; total time=   0.1s[CV] END .................C=5.150000000000001, kernel=linear; total time=   0.0s
#
# [CV] END .................C=5.100000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.250000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.050000000000002, kernel=linear; total time=   0.1s[CV] END .................C=5.150000000000001, kernel=linear; total time=   0.0s
#
# [CV] END .................C=5.100000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.200000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.250000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.250000000000002, kernel=linear; total time=   0.1s[CV] END .................C=5.150000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.300000000000002, kernel=linear; total time=   0.1s
#
# [CV] END .................C=5.350000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.100000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.200000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.300000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.250000000000002, kernel=linear; total time=   0.1s[CV] END .................C=5.300000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.400000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=5.450000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.350000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.300000000000002, kernel=linear; total time=   0.1s[CV] END .................C=5.400000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=5.300000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.400000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.500000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.450000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.350000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.500000000000002, kernel=linear; total time=   0.1s[CV] END .................C=5.550000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.400000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.450000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=5.350000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.350000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.500000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.550000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.500000000000002, kernel=linear; total time=   0.1s[CV] END .................C=5.450000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.400000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.600000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=5.500000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.600000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.550000000000002, kernel=linear; total time=   0.1s[CV] END .................C=5.450000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=5.650000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.550000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.600000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.650000000000001, kernel=linear; total time=   0.1s[CV] END .................C=5.700000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=5.550000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.650000000000001, kernel=linear; total time=   0.1s[CV] END .................C=5.750000000000002, kernel=linear; total time=   0.1s
#
# [CV] END .................C=5.800000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.600000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.700000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.650000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.700000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.750000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.800000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.800000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.650000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.700000000000001, kernel=linear; total time=   0.1s[CV] END .................C=5.600000000000001, kernel=linear; total time=   0.1s
#
# [CV] END .................C=5.750000000000002, kernel=linear; total time=   0.1s[CV] END .................C=5.700000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.900000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.800000000000002, kernel=linear; total time=   0.1s
#
# [CV] END .................C=5.850000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.850000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.750000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.750000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.850000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.800000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.900000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=5.950000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.850000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=6.000000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.900000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=6.000000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.850000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=6.050000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.950000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=5.900000000000001, kernel=linear; total time=   0.1s
# ...
# [CV] END .................C=73.05000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=73.10000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.00000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=73.15000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.20000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.20000000000002, kernel=linear; total time=   0.1s[CV] END .................C=73.10000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.05000000000003, kernel=linear; total time=   0.1s[CV] END .................C=73.10000000000002, kernel=linear; total time=   0.0s
#
# [CV] END .................C=73.00000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=73.15000000000002, kernel=linear; total time=   0.0s
#
# [CV] END .................C=73.20000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.05000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=73.10000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.10000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.15000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.25000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=73.25000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=73.20000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.15000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.25000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=73.30000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=73.20000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.15000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.25000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=73.35000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.30000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=73.40000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.40000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.45000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.30000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=73.40000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.30000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=73.25000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=73.45000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.35000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.45000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.50000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=73.40000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.30000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=73.55000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=73.45000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.50000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=73.50000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=73.40000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.35000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.45000000000002, kernel=linear; total time=   0.1s[CV] END .................C=73.55000000000003, kernel=linear; total time=   0.1s
#
# [CV] END .................C=73.50000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=73.35000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.60000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.50000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=73.60000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.55000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=73.55000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=73.65000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.35000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.60000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.70000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.65000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.55000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=73.65000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.75000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=73.60000000000002, kernel=linear; total time=   0.1s[CV] END .................C=73.80000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=73.80000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=73.65000000000002, kernel=linear; total time=   0.1s
#
# [CV] END .................C=73.70000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.70000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.60000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.70000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.85000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.75000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=73.80000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=73.65000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.85000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.75000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=73.75000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=73.90000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.85000000000002, kernel=linear; total time=   0.1s[CV] END .................C=73.80000000000003, kernel=linear; total time=   0.1s
#
# [CV] END .................C=73.70000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.85000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.75000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=73.85000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.95000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.00000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=73.80000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=73.90000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.05000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=74.00000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=73.90000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.95000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.05000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=74.05000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=74.10000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=73.90000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.90000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.00000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=73.95000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.10000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.10000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.05000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=74.00000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=73.95000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=73.95000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.15000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.10000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.10000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.05000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=74.00000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=74.15000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.20000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.20000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.25000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=74.15000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.30000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=74.35000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.15000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.25000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=74.20000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.30000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=74.25000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=74.40000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.35000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.15000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.25000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=74.20000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.30000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=74.30000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=74.40000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.35000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.40000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.35000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.20000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.30000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=74.40000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.25000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=74.35000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.45000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.40000000000002, kernel=linear; total time=   0.0s[CV] END .................C=74.45000000000002, kernel=linear; total time=   0.1s
#
# [CV] END .................C=74.50000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=74.55000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=74.60000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.45000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.45000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.55000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=74.65000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.50000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=74.60000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.60000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.50000000000001, kernel=linear; total time=   0.0s
# [CV] END .................C=74.45000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.55000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=74.65000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.50000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=74.65000000000002, kernel=linear; total time=   0.1s[CV] END .................C=74.50000000000001, kernel=linear; total time=   0.0s[CV] END .................C=74.60000000000002, kernel=linear; total time=   0.1s
#
# [CV] END .................C=74.55000000000003, kernel=linear; total time=   0.0s
# [CV] END .................C=74.70000000000002, kernel=linear; total time=   0.1s[CV] END .................C=74.55000000000003, kernel=linear; total time=   0.1s
#
#
# [CV] END .................C=74.70000000000002, kernel=linear; total time=   0.1s[CV] END .................C=74.60000000000002, kernel=linear; total time=   0.1s
#
# [CV] END .................C=74.80000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=74.80000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=74.65000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.70000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.70000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.75000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=74.80000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=74.85000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.65000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.90000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.85000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.75000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=74.70000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.80000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=74.95000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.75000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=74.80000000000003, kernel=linear; total time=   0.1s
# [CV] END .................C=74.90000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.85000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.85000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.75000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=74.95000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.75000000000001, kernel=linear; total time=   0.1s
# [CV] END .................C=74.90000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.90000000000002, kernel=linear; total time=   0.1s
# [CV] END .................C=74.85000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.95000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.95000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.90000000000002, kernel=linear; total time=   0.0s
# [CV] END .................C=74.95000000000002, kernel=linear; total time=   0.0s
# Training done in 100.40333819389343s
# Support Vector Machine best estimator found using grid search: SVC(C=51.45000000000002, kernel='linear')

# %% [markdown]
# ### Create the final model using the best estimator found

# %%
print("Creating final Support Vector Machine model...")
svm_model = svm_model_best_estimator
print("Training final Support Vector Machine model...")
t_start = time()
svm_model.fit(X_train,Y_train)
print("\ttraining done in {}s".format(time()-t_start))

print("Testing final Support Vector Machine model...")
preds_valid=svm_model.predict(X_test)

# Metrics off the dataset
print(classification_report(Y_test, preds_valid, target_names=unique_label_names))
# Plot confusion matrix
ConfusionMatrixDisplay.from_predictions(Y_test, preds_valid, display_labels=unique_label_names)
plt.title("Support Vector Machine Confusion matrix")
plt.show()
# plot_confusion_matrix(y_test_index, preds_valid_id, classes=unique_label_names, title='Support Vector Machine Confusion matrix')
# Out:
# Creating final Support Vector Machine model...
# Training final Support Vector Machine model...
# 	training done in 0.03782916069030762s
# Testing final Support Vector Machine model...
#               precision    recall  f1-score   support
#
#        blues       0.78      0.86      0.82        21
#    classical       1.00      0.95      0.97        20
#      country       0.71      0.85      0.77        20
#        disco       0.52      0.65      0.58        20
#       hiphop       0.62      0.40      0.48        20
#         jazz       0.93      0.70      0.80        20
#        metal       0.85      0.85      0.85        20
#          pop       0.74      0.70      0.72        20
#       reggae       0.68      0.75      0.71        20
#         rock       0.38      0.40      0.39        20
#
#     accuracy                           0.71       201
#    macro avg       0.72      0.71      0.71       201
# weighted avg       0.72      0.71      0.71       201

# %% [markdown]
# ### Export model to csv file

# %%
CSV_HEADER = svm_to_csv(svm_model, class_names=unique_label_names, csv_file=SVM_MODEL_CSV)

print("CSV file  path: {}".format(SVM_MODEL_CSV))
print("CSV file  header: {}".format(CSV_HEADER))
# Out:
# CSV file  path: ./support_vector_machine_mfcc.csv
# CSV file  header: ['positive_class', 'negative_class', 'intercept', 'coeff0', 'coeff1', 'coeff2', 'coeff3', 'coeff4', 'coeff5', 'coeff6', 'coeff7', 'coeff8', 'coeff9', 'coeff10', 'coeff11', 'coeff12', 'coeff13', 'coeff14', 'coeff15', 'coeff16', 'coeff17', 'coeff18', 'coeff19', 'coeff20', 'coeff21', 'coeff22', 'coeff23', 'coeff24', 'coeff25', 'coeff26', 'coeff27', 'coeff28', 'coeff29', 'coeff30', 'coeff31', 'coeff32', 'coeff33', 'coeff34', 'coeff35', 'coeff36', 'coeff37', 'coeff38', 'coeff39', 'coeff40', 'coeff41']
